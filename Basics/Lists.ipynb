# %%
numbers = [10, 20, 30, 50, 100, 110, 120, 130]
names = ["mujahid", "hammad", "ahamd", "adan"]
mixed = ["saad", 5.8, 22]

# %%
# list comprehension
products = [n * 2 for n in numbers]

# %%
products
# Out:
# [20, 40, 60, 100, 200, 220, 240, 260]

# %%
# accessing
# numbers[2]
numbers[:4]  # start to 3
# Out:
# [10, 20, 30, 50]

# %%
numbers[1:6:2]  # starts from index 1 , ends on 6(exc) skipping 1 element in between
# Out:
# [20, 50, 110]

# %%
names[0] = "mujahid islam"
names.append("ishmal")

# %%
names
# Out:
# ['mujahid islam', 'hammad', 'ahamd', 'adan', 'ishmal']

# %%
names.insert(2, "aidwa")

# %%
names
# Out:
# ['mujahid islam', 'hammad', 'aidwa', 'ahamd', 'adan', 'ishmal']

# %%
names.remove("mujahid islam")

# %%
names
# Out:
# ['hammad', 'aidwa', 'ahamd', 'adan', 'ishmal']

# %%
for n in names:
    print(n)
# Out:
# hammad
# aidwa
# ahamd
# adan
# ishmal

# %%
# getting index and value
for i, name in enumerate(names):
    print(i, name)
# Out:
# 0 hammad
# 1 aidwa
# 2 ahamd
# 3 adan
# 4 ishmal

# %%
len(names)
# Out:
# 5

# %%
matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

print(matrix[1][2])
# Out:
# 6

# %%
a = [1, 2, 3]
b = a

b.append(4)
print(a)  # a will be modified
# Out:
# [1, 2, 3, 4]

# %%
b = a.copy()

# %%
b
# Out:
# [1, 2, 3, 4]
