# %%
student = {"name": "Ali", "age": 20, "grade": "A"}

# %%
print(student["name"])
# Out:
# Ali

# %%
print(student.get("name"))
print(student.get("marks"))
# Out:
# Ali
# None

# %%
student["age"] = 21
student["name"] = "Sara"

# %%
student
# Out:
# {'name': 'Sara', 'age': 21, 'grade': 'A'}

# %%
for key in student:
    # print(key)
    print(key, student[key])
# Out:
# name Sara
# age 21
# grade A

# %%
for key, value in student.items():
    print(key, value)
# Out:
# name Sara
# age 21
# grade A

# %%
# student.keys()   # only keys
# student.values()  # only values
student.items()  # key,value
# Out:
# dict_items([('name', 'Sara'), ('age', 21), ('grade', 'A')])
