# %%
names = ("mujahid", "ahmad", "ali")
names
# Out:
# ('mujahid', 'ahmad', 'ali')

# %%
names[1] = "ali"  # immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 names[1]="ali"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = 1, 2, 3  # automatically becomes tuple
t
# Out:
# (1, 2, 3)

# %%
a, b, c = (1, 2, 3)

print(a)
# Out:
# 1

# %%
a, b, *c = (1, 2, 3, 4)

print(a)
print(b)
print(c)
# Out:
# 1
# 2
# [3, 4]

# %%
# used to return multiple values from functions
def get_user():
    return ("Ali", 25)


name, age = get_user()
print(name, age)
# Out:
# Ali 25
