# %%
names = {1, 2, 3, 3}

# %%
names
# Out:
# {1, 2, 3}

# %%
names[0]  # error since sets are unordered
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 names[0]
#
# TypeError: 'set' object is not subscriptable

# %%
names.add(20)

# %%
names
# Out:
# {1, 2, 3, 20}

# %%
s = {1, 2}

s.add(3)
s.update([4])

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
a = {1, 2}
b = {2, 3}

print(a | b)  # union of sets
# Out:
# {1, 2, 3}

# %%
a = {1, 2}
b = {2, 3}
print(a & b)  # intersection
# Out:
# {2}
