# %%
import sys

print(sys.argv)
# Out:
# ['/home/mrmacbook/Desktop/Training/Python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel_launcher.py', '--f=/run/user/1000/jupyter/runtime/kernel-v3241208923ccd3742310b352407a7136744295e34.json']
